# %%
import pandas as pd
import numpy as np

# %%
# Load in data
atp_ranks = pd.read_csv("data/atp_ranks.csv")
wta_ranks = pd.read_csv("data/wta_ranks.csv")
womens_stats = pd.read_csv("data/womens_df_prod.csv")
mens_stats = pd.read_csv("data/mens_df_prod.csv")

# %% [markdown]
# Merge rankings data

# %%
# Tied rankings
atp_ranks[~atp_ranks['rank'].str.isnumeric()]
# Out:
#                          player   rank        week
# 903                Pablo Cuevas   904T  2023-06-26
# 904                   Adam Neff   904T  2023-06-26
# 923         Menelaos Efstathiou   924T  2023-06-26
# 924                John McNally   924T  2023-06-26
# 1001          Lorenzo Gagliardo  1002T  2023-06-26
# ...                         ...    ...         ...
# 8143            Youssef Labbene  2057T  2023-08-22
# 8144        Ignacio Benzal Alia  2061T  2023-08-22
# 8145           Akram El Sallaly  2061T  2023-08-22
# 8146  Abhinav Sanjeev Shanmugam  2061T  2023-08-22
# 8147              Ioannis Xilas  2061T  2023-08-22
#
# [3374 rows x 3 columns]

# %%
# Remove T from the rank
atp_ranks['rank_cleaned'] = pd.to_numeric(atp_ranks['rank'].str.replace('T', ''), errors='coerce')

# %%
atp_ranks['player_cleaned'] = atp_ranks['player'].apply(lambda word: " ".join(word.split()[1:])+", "+word.split()[0])
atp_ranks
# Out:
#                          player   rank        week  rank_cleaned  \
# 0                Carlos Alcaraz      1  2023-06-26             1
# 1                Novak Djokovic      2  2023-06-26             2
# 2               Daniil Medvedev      3  2023-06-26             3
# 3                   Casper Ruud      4  2023-06-26             4
# 4            Stefanos Tsitsipas      5  2023-06-26             5
# ...                         ...    ...         ...           ...
# 8145           Akram El Sallaly  2061T  2023-08-22          2061
# 8146  Abhinav Sanjeev Shanmugam  2061T  2023-08-22          2061
# 8147              Ioannis Xilas  2061T  2023-08-22          2061
# 8148              Jesse Delaney   2065  2023-08-22          2065
# 8149             Aleksa Pisaric   2066  2023-08-22          2066
#
#                   player_cleaned
# 0                Alcaraz, Carlos
# 1                Djokovic, Novak
# 2               Medvedev, Daniil
# 3                   Ruud, Casper
# 4            Tsitsipas, Stefanos
# ...                          ...
# 8145           El Sallaly, Akram
# 8146  Sanjeev Shanmugam, Abhinav
# 8147              Xilas, Ioannis
# 8148              Delaney, Jesse
# 8149             Pisaric, Aleksa
#
# [8150 rows x 5 columns]

# %%
wta_ranks
# Out:
#                           player    rank        week
# 0                    Swiatek Iga     1.0  2023-06-26
# 1                Sabalenka Aryna     2.0  2023-06-26
# 2                 Rybakina Elena     3.0  2023-06-26
# 3                 Pegula Jessica     4.0  2023-06-26
# 4                Garcia Caroline     5.0  2023-06-26
# ...                          ...     ...         ...
# 5511              Faltinger Ines  1390.0  2023-08-22
# 5512  Goldsmith Weinreich Paloma  1390.0  2023-08-22
# 5513       Ionescu Iulia Andreea  1390.0  2023-08-22
# 5514                  Joint Maya  1390.0  2023-08-22
# 5515                   Kim Haram  1390.0  2023-08-22
#
# [5516 rows x 3 columns]

# %%
# Move the first name to the front
# This doesn't accont for people with two first names but I think those may be edge cases I don't need to worry about for now
def move_first(names):
    names = names.split()
    ret = names[0:-1]
    ret.insert(0, names[-1])
    return " ".join(ret)


wta_ranks['player_cleaned'] = wta_ranks['player'].apply(move_first)
wta_ranks['player_cleaned'] = wta_ranks['player_cleaned'].apply(lambda word: " ".join(word.split()[1:])+", "+word.split()[0])
wta_ranks
# Out:
#                           player    rank        week  \
# 0                    Swiatek Iga     1.0  2023-06-26
# 1                Sabalenka Aryna     2.0  2023-06-26
# 2                 Rybakina Elena     3.0  2023-06-26
# 3                 Pegula Jessica     4.0  2023-06-26
# 4                Garcia Caroline     5.0  2023-06-26
# ...                          ...     ...         ...
# 5511              Faltinger Ines  1390.0  2023-08-22
# 5512  Goldsmith Weinreich Paloma  1390.0  2023-08-22
# 5513       Ionescu Iulia Andreea  1390.0  2023-08-22
# 5514                  Joint Maya  1390.0  2023-08-22
# 5515                   Kim Haram  1390.0  2023-08-22
#
#                    player_cleaned
# 0                    Swiatek, Iga
# 1                Sabalenka, Aryna
# 2                 Rybakina, Elena
# 3                 Pegula, Jessica
# 4                Garcia, Caroline
# ...                           ...
# 5511              Faltinger, Ines
# 5512  Goldsmith Weinreich, Paloma
# 5513       Ionescu Iulia, Andreea
# 5514                  Joint, Maya
# 5515                   Kim, Haram
#
# [5516 rows x 4 columns]

# %%
atp_ranks.columns
# Out:
# Index(['player', 'rank', 'week', 'rank_cleaned', 'player_cleaned'], dtype='object')

# %%
wta_ranks = wta_ranks.drop(columns = ["player"])
atp_ranks = atp_ranks.drop(columns = ['player','rank'])
atp_ranks = atp_ranks.rename(columns ={"rank_cleaned":"rank"})

# %%
ranks = pd.concat([atp_ranks, wta_ranks])
ranks = ranks.rename(columns = {'week':'date','player_cleaned':'player'})
ranks
# Out:
#             date    rank                       player
# 0     2023-06-26     1.0              Alcaraz, Carlos
# 1     2023-06-26     2.0              Djokovic, Novak
# 2     2023-06-26     3.0             Medvedev, Daniil
# 3     2023-06-26     4.0                 Ruud, Casper
# 4     2023-06-26     5.0          Tsitsipas, Stefanos
# ...          ...     ...                          ...
# 5511  2023-08-22  1390.0              Faltinger, Ines
# 5512  2023-08-22  1390.0  Goldsmith Weinreich, Paloma
# 5513  2023-08-22  1390.0       Ionescu Iulia, Andreea
# 5514  2023-08-22  1390.0                  Joint, Maya
# 5515  2023-08-22  1390.0                   Kim, Haram
#
# [13666 rows x 3 columns]

# %%
ranks['player'] = ranks["player"].apply(lambda x: x.title())
ranks.to_csv("data/ranks.csv", index=False)

# %%
stats = pd.concat([womens_stats, mens_stats])
stats[["name_home","name_away"]] = stats[["name_home","name_away"]].apply(lambda column: column.apply(lambda x: x.title()))
stats
# Out:
#                     event_id        player_id_home              name_home  \
# 0    sr:sport_event:42023445   sr:competitor:66968  Kudermetova, Veronika
# 1    sr:sport_event:42023447   sr:competitor:41355            Bogdan, Ana
# 2    sr:sport_event:42023449  sr:competitor:256547          Parks, Alycia
# 3    sr:sport_event:42023459   sr:competitor:99131        Bucsa, Cristina
# 4    sr:sport_event:42023461   sr:competitor:44834        Pegula, Jessica
# ..                       ...                   ...                    ...
# 490  sr:sport_event:43216857  sr:competitor:163504       Medvedev, Daniil
# 491  sr:sport_event:43216863  sr:competitor:407573        Alcaraz, Carlos
# 492  sr:sport_event:43216849  sr:competitor:808628           Shelton, Ben
# 493  sr:sport_event:43216855  sr:competitor:407573        Alcaraz, Carlos
# 494  sr:sport_event:43216851  sr:competitor:163504       Medvedev, Daniil
#
#      seed_home  aces_home  backhand_errors_home  \
# 0         12.0         14                    13
# 1          NaN          6                    12
# 2          NaN          5                     8
# 3          NaN          6                    34
# 4          4.0          3                    20
# ..         ...        ...                   ...
# 490        3.0          8                    10
# 491        1.0          3                     5
# 492        NaN          5                    20
# 493        1.0          0                    25
# 494        3.0          6                    12
#
#      backhand_unforced_errors_home  backhand_winners_home  \
# 0                                8                      9
# 1                                7                      7
# 2                               17                      3
# 3                               15                     10
# 4                               14                     11
# ..                             ...                    ...
# 490                             11                      7
# 491                             10                     12
# 492                             11                      4
# 493                             14                     12
# 494                             22                      6
#
#      breakpoints_won_home  double_faults_home  ...  games_won  \
# 0                       1                   1  ...        NaN
# 1                       3                   2  ...        NaN
# 2                       4                   5  ...        NaN
# 3                       6                   4  ...        NaN
# 4                       5                   3  ...        NaN
# ..                    ...                 ...  ...        ...
# 490                     9                   9  ...        NaN
# 491                     4                   3  ...        NaN
# 492                     2                   5  ...        NaN
# 493                     1                   0  ...        NaN
# 494                     1                   6  ...        NaN
#
#      max_games_in_a_row  avg_game_length_set4  set4_length  \
# 0                   NaN                   NaN          NaN
# 1                   NaN                   NaN          NaN
# 2                   NaN                   NaN          NaN
# 3                   NaN                   NaN          NaN
# 4                   NaN                   NaN          NaN
# ..                  ...                   ...          ...
# 490                 NaN                   NaN          NaN
# 491                 NaN                   NaN          NaN
# 492                 NaN                   NaN          NaN
# 493                 NaN              6.661111        59.95
# 494                 NaN                   NaN          NaN
#
#      avg_game_length_set5  set5_length  set4_diff  set4_games  set5_diff  \
# 0                     NaN          NaN        NaN         NaN        NaN
# 1                     NaN          NaN        NaN         NaN        NaN
# 2                     NaN          NaN        NaN         NaN        NaN
# 3                     NaN          NaN        NaN         NaN        NaN
# 4                     NaN          NaN        NaN         NaN        NaN
# ..                    ...          ...        ...         ...        ...
# 490                   NaN          NaN        NaN         NaN        NaN
# 491                   NaN          NaN        NaN         NaN        NaN
# 492                   NaN          NaN        NaN         NaN        NaN
# 493                   NaN          NaN       -3.0         9.0        NaN
# 494                   NaN          NaN        NaN         NaN        NaN
#
#      set5_games
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 490         NaN
# 491         NaN
# 492         NaN
# 493         NaN
# 494         NaN
#
# [988 rows x 114 columns]

# %%
stats_c = stats[["date","name_home", "seed_home", "name_away", "seed_away","men"]]
stats_c
# Out:
#            date              name_home  seed_home            name_away  \
# 0    2023-06-26  Kudermetova, Veronika       12.0         Kanepi, Kaia
# 1    2023-06-26            Bogdan, Ana        NaN  Samsonova, Liudmila
# 2    2023-06-26          Parks, Alycia        NaN  Friedsam, Anna-Lena
# 3    2023-06-26        Bucsa, Cristina        NaN   Rakhimova, Kamilla
# 4    2023-06-26        Pegula, Jessica        4.0        Davis, Lauren
# ..          ...                    ...        ...                  ...
# 490  2023-08-22       Medvedev, Daniil        3.0       Rublev, Andrey
# 491  2023-08-22        Alcaraz, Carlos        1.0    Zverev, Alexander
# 492  2023-08-22           Shelton, Ben        NaN      Djokovic, Novak
# 493  2023-08-22        Alcaraz, Carlos        1.0     Medvedev, Daniil
# 494  2023-08-22       Medvedev, Daniil        3.0      Djokovic, Novak
#
#      seed_away    men
# 0          NaN  False
# 1         15.0  False
# 2          NaN  False
# 3          NaN  False
# 4          NaN  False
# ..         ...    ...
# 490        8.0   True
# 491       12.0   True
# 492        2.0   True
# 493        3.0   True
# 494        2.0   True
#
# [988 rows x 6 columns]

# %%
print("stats_c")

for col in stats_c.columns:
    if any(stats_c[col].isna()):
        print(col)

print("ranks")
for col in ranks.columns:
    if any(ranks[col].isna()):
        print(col)
# Out:
# stats_c
# seed_home
# seed_away
# ranks

# %% [markdown]
# Merging ranks and stats

# %%
import regex as re
from functools import reduce

# %%
# merge stats and ranks (only for home)
merged = stats.merge(ranks, how = "left", left_on=["date","name_home"], right_on=["date","player"]).rename(columns={"rank":"rank_home","player":"player_home"})

# %%
# Find missing players for home
missing_players = []
found_players = []
to_fix = []
for row in merged[(merged['rank_home'].isna())].iterrows():
    name = row[1].name_home
    name_list = re.split(", | ",name)
    potential_ppl = []
    for part in name_list:
        exists = ranks['player'].apply(lambda x: bool(re.search(part, x, flags=re.IGNORECASE)))
        potential_ppl.append(ranks[exists])
    
    found = reduce(lambda x, y: pd.merge(x, y, on=['date','rank','player']), potential_ppl)
    if found.empty:
        # Try again only search for last name
        exists = ranks['player'].apply(lambda x: bool(re.search(name_list[0], x, flags=re.IGNORECASE)))
        found = ranks[exists]
        if len(found)==4:
            if name not in found_players:
                print(f"FOUND: {name}")
                corrected_values = found.copy()
                corrected_values.loc[:, 'player_corrected'] = name
                to_fix.append(ranks.merge(corrected_values, on=["date", 'rank','player']))
                found_players.append(name)
        else:
            if name not in missing_players:
                print(f"LOST: {name}")
                missing_players.append(name)
        
    else:
        if name not in found_players:
            print(f"FOUND: {name}")
            corrected_values = found.copy()
            corrected_values.loc[:,'player_corrected'] = name
            to_fix.append(ranks.merge(corrected_values, on=["date", 'rank','player']))
            found_players.append(name)

# # represents a new dataframe of the remaining ranked players that were missed in the previous iteration
missed_ranks = pd.concat(to_fix)
missed_ranks = missed_ranks.drop_duplicates()

merged2 = merged.merge(missed_ranks, how = "left", left_on=["date","name_home"], right_on=["date","player_corrected"])#.drop(columns=["player_x","player_y"])
merged2['name_home'] = merged2.apply(lambda row: row['name_home'] if pd.isna(row['player_corrected']) else row['player_corrected'], axis=1)
merged2['rank_home'] = merged2.apply(lambda row: row['rank_home'] if pd.isna(row['rank']) else row['rank'], axis=1)
# Out:
# FOUND: Yuan, Yue
# FOUND: Tsurenko, Lesia
# FOUND: Burrage, Jodie Anna
# FOUND: Kasatkina, Daria
# FOUND: Cirstea, Sorana
# LOST: Cristian, Jaqueline Adina
# FOUND: Stephens, Sloane
# FOUND: Minnen, Greet
# LOST: Riske-Amritraj, Alison
# FOUND: Begu, Irina-Camelia
# LOST: Fernandez, Leylah Annie
# FOUND: Andreescu, Bianca
# FOUND: Azarenka, Victoria
# FOUND: Parrizas Diaz, Nuria
# FOUND: Samsonova, Liudmila
# LOST: Maria, Tatjana
# FOUND: Schmiedlova, Anna-Karolina
# FOUND: Krunic, Aleksandra
# FOUND: Gauff, Coco
# FOUND: Miyazaki, Yuriko Lily
# FOUND: Tig, Patricia Maria
# LOST: Wolf, Jeffrey John
# FOUND: Etcheverry, Tomas Martin
# FOUND: Galan, Daniel Elahi
# FOUND: Barrios Vera, Marcelo Tomas
# FOUND: Tirante, Thiago Agustin
# FOUND: Olivieri, Genaro Alberto
# FOUND: Varillas, Juan Pablo
# FOUND: Cerundolo, Juan Manuel
# FOUND: Hsu, Yu Hsiou

# %%
merged2 = merged2.drop(columns = ["rank","player","player_corrected","player_home"])
merged2
# Out:
#                     event_id        player_id_home              name_home  \
# 0    sr:sport_event:42023445   sr:competitor:66968  Kudermetova, Veronika
# 1    sr:sport_event:42023447   sr:competitor:41355            Bogdan, Ana
# 2    sr:sport_event:42023449  sr:competitor:256547          Parks, Alycia
# 3    sr:sport_event:42023459   sr:competitor:99131        Bucsa, Cristina
# 4    sr:sport_event:42023461   sr:competitor:44834        Pegula, Jessica
# ..                       ...                   ...                    ...
# 983  sr:sport_event:43216857  sr:competitor:163504       Medvedev, Daniil
# 984  sr:sport_event:43216863  sr:competitor:407573        Alcaraz, Carlos
# 985  sr:sport_event:43216849  sr:competitor:808628           Shelton, Ben
# 986  sr:sport_event:43216855  sr:competitor:407573        Alcaraz, Carlos
# 987  sr:sport_event:43216851  sr:competitor:163504       Medvedev, Daniil
#
#      seed_home  aces_home  backhand_errors_home  \
# 0         12.0         14                    13
# 1          NaN          6                    12
# 2          NaN          5                     8
# 3          NaN          6                    34
# 4          4.0          3                    20
# ..         ...        ...                   ...
# 983        3.0          8                    10
# 984        1.0          3                     5
# 985        NaN          5                    20
# 986        1.0          0                    25
# 987        3.0          6                    12
#
#      backhand_unforced_errors_home  backhand_winners_home  \
# 0                                8                      9
# 1                                7                      7
# 2                               17                      3
# 3                               15                     10
# 4                               14                     11
# ..                             ...                    ...
# 983                             11                      7
# 984                             10                     12
# 985                             11                      4
# 986                             14                     12
# 987                             22                      6
#
#      breakpoints_won_home  double_faults_home  ...  max_games_in_a_row  \
# 0                       1                   1  ...                 NaN
# 1                       3                   2  ...                 NaN
# 2                       4                   5  ...                 NaN
# 3                       6                   4  ...                 NaN
# 4                       5                   3  ...                 NaN
# ..                    ...                 ...  ...                 ...
# 983                     9                   9  ...                 NaN
# 984                     4                   3  ...                 NaN
# 985                     2                   5  ...                 NaN
# 986                     1                   0  ...                 NaN
# 987                     1                   6  ...                 NaN
#
#      avg_game_length_set4  set4_length  avg_game_length_set5  set5_length  \
# 0                     NaN          NaN                   NaN          NaN
# 1                     NaN          NaN                   NaN          NaN
# 2                     NaN          NaN                   NaN          NaN
# 3                     NaN          NaN                   NaN          NaN
# 4                     NaN          NaN                   NaN          NaN
# ..                    ...          ...                   ...          ...
# 983                   NaN          NaN                   NaN          NaN
# 984                   NaN          NaN                   NaN          NaN
# 985                   NaN          NaN                   NaN          NaN
# 986              6.661111        59.95                   NaN          NaN
# 987                   NaN          NaN                   NaN          NaN
#
#      set4_diff  set4_games  set5_diff  set5_games  rank_home
# 0          NaN         NaN        NaN         NaN       12.0
# 1          NaN         NaN        NaN         NaN       61.0
# 2          NaN         NaN        NaN         NaN       47.0
# 3          NaN         NaN        NaN         NaN       77.0
# 4          NaN         NaN        NaN         NaN        4.0
# ..         ...         ...        ...         ...        ...
# 983        NaN         NaN        NaN         NaN        3.0
# 984        NaN         NaN        NaN         NaN        1.0
# 985        NaN         NaN        NaN         NaN       46.0
# 986       -3.0         9.0        NaN         NaN        1.0
# 987        NaN         NaN        NaN         NaN        3.0
#
# [988 rows x 115 columns]

# %%
# # Do the same thing for away
merged = merged2.merge(ranks, how = "left", left_on=["date","name_away"], right_on=["date","player"]).rename(columns={"rank":"rank_away","player":"player_away"})

# Find missing players for home
found_players = []
to_fix = []
for row in merged[(merged['rank_away'].isna())].iterrows():
    name = row[1].name_away
    name_list = re.split(", | ",name)
    potential_ppl = []
    for part in name_list:
        exists = ranks['player'].apply(lambda x: bool(re.search(part, x, flags=re.IGNORECASE)))
        potential_ppl.append(ranks[exists])
    
    found = reduce(lambda x, y: pd.merge(x, y, on=['date','rank','player']), potential_ppl)
    if found.empty:
        # Try again only search for last name
        exists = ranks['player'].apply(lambda x: bool(re.search(name_list[0], x, flags=re.IGNORECASE)))
        found = ranks[exists]
        if len(found)==4:
            if name not in found_players:
                print(f"FOUND: {name}")
                corrected_values = found.copy()
                corrected_values.loc[:, 'player_corrected'] = name
                to_fix.append(ranks.merge(corrected_values, on=["date", 'rank','player']))
                found_players.append(name)
        else:
            if name not in missing_players:
                print(f"LOST: {name}")
                missing_players.append(name)
        
    else:
        if name not in found_players:
            print(f"FOUND: {name}")
            corrected_values = found.copy()
            corrected_values.loc[:,'player_corrected'] = name
            to_fix.append(ranks.merge(corrected_values, on=["date", 'rank','player']))
            found_players.append(name)

missed_ranks = pd.concat(to_fix)
missed_ranks = missed_ranks.drop_duplicates()

merged2 = merged.merge(missed_ranks, how = "left", left_on=["date","name_away"], right_on=["date","player_corrected"])
merged2['name_away'] = merged2.apply(lambda row: row['name_away'] if pd.isna(row['player_corrected']) else row['player_corrected'], axis=1)
merged2['rank_away'] = merged2.apply(lambda row: row['rank_away'] if pd.isna(row['rank']) else row['rank'], axis=1)
# Out:
# FOUND: Samsonova, Liudmila
# FOUND: Azarenka, Victoria
# FOUND: Teichmann, Jil
# LOST: Mcnally, Catherine
# FOUND: Gauff, Coco
# FOUND: Burrage, Jodie Anna
# FOUND: Schmiedlova, Anna-Karolina
# FOUND: Parrizas Diaz, Nuria
# FOUND: Tsurenko, Lesia
# FOUND: Andreescu, Bianca
# FOUND: Cirstea, Sorana
# FOUND: Begu, Irina-Camelia
# FOUND: Kasatkina, Daria
# FOUND: Stephens, Sloane
# FOUND: Starodubtseva, Yuliia
# FOUND: Osaka, Naomi
# FOUND: Kerber, Angelique
# FOUND: Yuan, Yue
# FOUND: Ruse, Elena-Gabriela
# FOUND: Minnen, Greet
# FOUND: Varillas, Juan Pablo
# FOUND: Barrios Vera, Marcelo Tomas
# FOUND: Galan, Daniel Elahi
# FOUND: Cerundolo, Juan Manuel
# FOUND: Tirante, Thiago Agustin
# FOUND: Olivieri, Genaro Alberto
# FOUND: Etcheverry, Tomas Martin
# FOUND: Balazs, Attila
# FOUND: Hsu, Yu Hsiou

# %%
# Only a few players could not be merged, we can just drop these or have a NA seed and rank
print(missing_players)
# Out:
# ['Cristian, Jaqueline Adina', 'Riske-Amritraj, Alison', 'Fernandez, Leylah Annie', 'Maria, Tatjana', 'Wolf, Jeffrey John', 'Mcnally, Catherine']

# %%
merged = merged2.drop(columns = ["rank","player","player_corrected","player_away"])
merged
# Out:
#                     event_id        player_id_home              name_home  \
# 0    sr:sport_event:42023445   sr:competitor:66968  Kudermetova, Veronika
# 1    sr:sport_event:42023447   sr:competitor:41355            Bogdan, Ana
# 2    sr:sport_event:42023449  sr:competitor:256547          Parks, Alycia
# 3    sr:sport_event:42023459   sr:competitor:99131        Bucsa, Cristina
# 4    sr:sport_event:42023461   sr:competitor:44834        Pegula, Jessica
# ..                       ...                   ...                    ...
# 983  sr:sport_event:43216857  sr:competitor:163504       Medvedev, Daniil
# 984  sr:sport_event:43216863  sr:competitor:407573        Alcaraz, Carlos
# 985  sr:sport_event:43216849  sr:competitor:808628           Shelton, Ben
# 986  sr:sport_event:43216855  sr:competitor:407573        Alcaraz, Carlos
# 987  sr:sport_event:43216851  sr:competitor:163504       Medvedev, Daniil
#
#      seed_home  aces_home  backhand_errors_home  \
# 0         12.0         14                    13
# 1          NaN          6                    12
# 2          NaN          5                     8
# 3          NaN          6                    34
# 4          4.0          3                    20
# ..         ...        ...                   ...
# 983        3.0          8                    10
# 984        1.0          3                     5
# 985        NaN          5                    20
# 986        1.0          0                    25
# 987        3.0          6                    12
#
#      backhand_unforced_errors_home  backhand_winners_home  \
# 0                                8                      9
# 1                                7                      7
# 2                               17                      3
# 3                               15                     10
# 4                               14                     11
# ..                             ...                    ...
# 983                             11                      7
# 984                             10                     12
# 985                             11                      4
# 986                             14                     12
# 987                             22                      6
#
#      breakpoints_won_home  double_faults_home  ...  avg_game_length_set4  \
# 0                       1                   1  ...                   NaN
# 1                       3                   2  ...                   NaN
# 2                       4                   5  ...                   NaN
# 3                       6                   4  ...                   NaN
# 4                       5                   3  ...                   NaN
# ..                    ...                 ...  ...                   ...
# 983                     9                   9  ...                   NaN
# 984                     4                   3  ...                   NaN
# 985                     2                   5  ...                   NaN
# 986                     1                   0  ...              6.661111
# 987                     1                   6  ...                   NaN
#
#      set4_length  avg_game_length_set5  set5_length  set4_diff  set4_games  \
# 0            NaN                   NaN          NaN        NaN         NaN
# 1            NaN                   NaN          NaN        NaN         NaN
# 2            NaN                   NaN          NaN        NaN         NaN
# 3            NaN                   NaN          NaN        NaN         NaN
# 4            NaN                   NaN          NaN        NaN         NaN
# ..           ...                   ...          ...        ...         ...
# 983          NaN                   NaN          NaN        NaN         NaN
# 984          NaN                   NaN          NaN        NaN         NaN
# 985          NaN                   NaN          NaN        NaN         NaN
# 986        59.95                   NaN          NaN       -3.0         9.0
# 987          NaN                   NaN          NaN        NaN         NaN
#
#      set5_diff  set5_games  rank_home  rank_away
# 0          NaN         NaN       12.0      101.0
# 1          NaN         NaN       61.0       15.0
# 2          NaN         NaN       47.0       87.0
# 3          NaN         NaN       77.0       70.0
# 4          NaN         NaN        4.0       44.0
# ..         ...         ...        ...        ...
# 983        NaN         NaN        3.0        8.0
# 984        NaN         NaN        1.0       12.0
# 985        NaN         NaN       46.0        2.0
# 986        NaN         NaN        1.0        3.0
# 987        NaN         NaN        3.0        2.0
#
# [988 rows x 116 columns]

# %%
merged['rs_home'] = merged['seed_home'].fillna(merged['rank_home'])
merged['rs_away'] = merged['seed_away'].fillna(merged['rank_away'])
merged['seed_home'] = merged['seed_home'].isna() # change to if seeded or not
merged['seed_away'] = merged['seed_away'].isna() # change to if seeded or not

# %%
merged.to_csv("data/merged.csv", index=False)
